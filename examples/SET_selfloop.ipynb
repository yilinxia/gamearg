# %%
import clingo
from gamearg import *
from IPython.display import display, Image
import pandas as pd
import concurrent
from concurrent.futures import ThreadPoolExecutor
import time

# %% [markdown]
# ## Generating Graph

# %% [markdown]
# With given `node_num`, program will be able to generate all possible edges

# %%
def graph_generating(node_num):
    def on_model(m):
        if str(m) == "":
            possible_graphs.append(str(m))
        else:
            elements = str(m).split(" ")
            elements_with_dot = [element + "." for element in elements]
            concatenated = " ".join(elements_with_dot)
            possible_graphs.append(concatenated)

    graph_log = """
    #const n = {}.
    node(1..n).
    {{move(X,Y): node(X), node(Y)}}.
    edge(X,Y):- move(X,Y).
    edge(X,Y):- move(Y,X).
    connected(X,Y) :- edge(X,Y).
    connected(X,Y) :- connected(X,Z), edge(Z,Y).
    :- node(X), node(Y), not connected(X,Y), X!=Y.
    #show move/2.
    """.format(node_num)
    # print(graph_log)
    ctl = clingo.Control()
    ctl.configuration.solve.models = "0"
    ctl.add("base", [], graph_log)
    ctl.ground([("base", [])])
    possible_graphs = []
    ctl.solve(on_model=on_model)
    return possible_graphs

# %%
possible_graphs = graph_generating(node_num=2)

# %%
possible_graphs
# Out:
# ['move(2,1).',
#  'move(2,1). move(2,2).',
#  'move(1,1). move(2,1).',
#  'move(1,1). move(2,1). move(2,2).',
#  'move(1,2).',
#  'move(1,1). move(1,2).',
#  'move(1,2). move(2,2).',
#  'move(1,1). move(1,2). move(2,2).',
#  'move(1,2). move(2,1).',
#  'move(1,2). move(2,1). move(2,2).',
#  'move(1,1). move(1,2). move(2,1).',
#  'move(1,1). move(1,2). move(2,1). move(2,2).']

# %% [markdown]
# ## Digest into Game Solver

# %% [markdown]
# Based on the `possible_graphs`, we need to digest them into game_solver one by one and ensure that the result will be 3-valued (dir=back and forward)

# %%
columns = [
    "node_number",
    "edge_number",
    "graph",
    "fw_node_wfs",
    "bw_node_wfs",
]
graph_cal = pd.DataFrame(columns=columns)
node_num = 1


def process_graph(graph, node_num):
    try:
        fw_node_wfs_df = node_wfs_cal(graph, "game", reverse=False)
        bw_node_wfs_df = node_wfs_cal(graph, "game", reverse=True)
        return {
            "node_number": node_num,
            "edge_number": len(graph.split(".")) - 1,
            "graph": graph,
            "fw_node_wfs": set(fw_node_wfs_df["wfs"]),
            "bw_node_wfs": set(bw_node_wfs_df["wfs"]),
        }
    except Exception as e:
        print(f"An error occurred while processing {graph}: {e}")
        return None


data_to_add = []
with ThreadPoolExecutor(max_workers=5) as executor:
    futures = []
    for node_num in range(1, 5):
        possible_graphs = graph_generating(node_num)
        if not possible_graphs or all(graph == "" for graph in possible_graphs):
            continue
        for graph in possible_graphs:
            if graph == "":
                continue
            else:
                futures.append(executor.submit(process_graph, graph, node_num))
    for future in concurrent.futures.as_completed(futures):
        result = future.result()
        if result:
            data_to_add.append(result)
graph_cal = pd.DataFrame(data_to_add, columns=columns)

# %%
graph_cal
# Out:
#        node_number  edge_number  \
# 0                3            4
# 1                3            4
# 2                3            5
# 3                3            6
# 4                3            4
# ...            ...          ...
# 61784            4            9
# 61785            4            8
# 61786            4            9
# 61787            4            9
# 61788            4           10
#
#                                                    graph  fw_node_wfs  \
# 0            move(1,3). move(2,1). move(2,2). move(2,3).  {won, lost}
# 1            move(2,1). move(2,3). move(3,1). move(3,2).  {won, lost}
# 2      move(1,1). move(1,3). move(2,1). move(2,3). mo...       {draw}
# 3      move(1,1). move(2,1). move(2,2). move(2,3). mo...       {draw}
# 4            move(1,1). move(1,3). move(2,1). move(2,3).  {won, lost}
# ...                                                  ...          ...
# 61784  move(1,1). move(1,4). move(2,2). move(2,4). mo...       {draw}
# 61785  move(1,4). move(2,2). move(2,4). move(3,3). mo...       {draw}
# 61786  move(1,1). move(1,4). move(2,2). move(2,4). mo...       {draw}
# 61787  move(1,4). move(2,2). move(2,4). move(3,3). mo...       {draw}
# 61788  move(1,1). move(1,4). move(2,2). move(2,4). mo...       {draw}
#
#        bw_node_wfs
# 0           {draw}
# 1           {draw}
# 2      {won, lost}
# 3           {draw}
# 4      {won, lost}
# ...            ...
# 61784       {draw}
# 61785       {draw}
# 61786       {draw}
# 61787       {draw}
# 61788       {draw}
#
# [61789 rows x 5 columns]

# %%
graph_cal["fw_len"] = graph_cal["fw_node_wfs"].apply(len)
graph_cal["bw_len"] = graph_cal["bw_node_wfs"].apply(len)

# %%
graph_cal[(graph_cal["fw_len"] == 3) & (graph_cal["bw_len"] == 3)].sort_values(
    ["node_number", "edge_number"]
)
# Out:
#        node_number  edge_number  \
# 142              4            4
# 517              4            4
# 593              4            4
# 638              4            4
# 895              4            4
# ...            ...          ...
# 57632            4            7
# 58134            4            7
# 58368            4            7
# 60546            4            7
# 60665            4            7
#
#                                                    graph        fw_node_wfs  \
# 142          move(1,2). move(1,3). move(3,4). move(4,4).  {won, draw, lost}
# 517          move(1,2). move(2,2). move(3,1). move(3,4).  {won, draw, lost}
# 593          move(2,1). move(3,1). move(4,3). move(4,4).  {won, draw, lost}
# 638          move(1,3). move(2,1). move(2,2). move(4,3).  {won, draw, lost}
# 895          move(1,4). move(2,1). move(3,1). move(3,3).  {won, draw, lost}
# ...                                                  ...                ...
# 57632  move(1,1). move(1,4). move(3,1). move(3,2). mo...  {won, draw, lost}
# 58134  move(2,2). move(2,4). move(3,1). move(3,4). mo...  {won, draw, lost}
# 58368  move(1,3). move(1,4). move(2,2). move(2,4). mo...  {won, draw, lost}
# 60546  move(1,1). move(1,4). move(2,3). move(2,4). mo...  {won, draw, lost}
# 60665  move(1,1). move(1,4). move(3,2). move(3,4). mo...  {won, draw, lost}
#
#              bw_node_wfs  fw_len  bw_len
# 142    {won, draw, lost}       3       3
# 517    {won, draw, lost}       3       3
# 593    {won, draw, lost}       3       3
# 638    {won, draw, lost}       3       3
# 895    {won, draw, lost}       3       3
# ...                  ...     ...     ...
# 57632  {won, draw, lost}       3       3
# 58134  {won, draw, lost}       3       3
# 58368  {won, draw, lost}       3       3
# 60546  {won, draw, lost}       3       3
# 60665  {won, draw, lost}       3       3
#
# [696 rows x 7 columns]

# %%
graph_cal[
    (graph_cal["fw_len"] == 3)
    & (graph_cal["bw_len"] == 3)
    & (graph_cal["node_number"] == 4)
    & (graph_cal["edge_number"] == 4)
].sort_values(["node_number", "edge_number"])
# Out:
#        node_number  edge_number                                        graph  \
# 142              4            4  move(1,2). move(1,3). move(3,4). move(4,4).
# 517              4            4  move(1,2). move(2,2). move(3,1). move(3,4).
# 593              4            4  move(2,1). move(3,1). move(4,3). move(4,4).
# 638              4            4  move(1,3). move(2,1). move(2,2). move(4,3).
# 895              4            4  move(1,4). move(2,1). move(3,1). move(3,3).
# ...            ...          ...                                          ...
# 61509            4            4  move(1,1). move(1,4). move(3,4). move(4,2).
# 61549            4            4  move(1,4). move(3,3). move(4,2). move(4,3).
# 61551            4            4  move(1,4). move(2,2). move(4,2). move(4,3).
# 61567            4            4  move(1,4). move(2,2). move(2,4). move(4,3).
# 61569            4            4  move(1,1). move(1,4). move(2,4). move(4,3).
#
#              fw_node_wfs        bw_node_wfs  fw_len  bw_len
# 142    {won, draw, lost}  {won, draw, lost}       3       3
# 517    {won, draw, lost}  {won, draw, lost}       3       3
# 593    {won, draw, lost}  {won, draw, lost}       3       3
# 638    {won, draw, lost}  {won, draw, lost}       3       3
# 895    {won, draw, lost}  {won, draw, lost}       3       3
# ...                  ...                ...     ...     ...
# 61509  {won, draw, lost}  {won, draw, lost}       3       3
# 61549  {won, draw, lost}  {won, draw, lost}       3       3
# 61551  {won, draw, lost}  {won, draw, lost}       3       3
# 61567  {won, draw, lost}  {won, draw, lost}       3       3
# 61569  {won, draw, lost}  {won, draw, lost}       3       3
#
# [96 rows x 7 columns]

# %%
# graph_cal.to_csv("graph_cal_selfloop.csv")
