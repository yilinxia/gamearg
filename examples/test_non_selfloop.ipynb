# %%
from gamearg import *
from IPython.display import display, Image

# %%
# You only need edit this cell
input_file = "files/SET_example_2.lp"
keyword = "game" #arg or game depends on the graphvis_settings.json
reverse = False  # whether you want to reverse the edge direction

# %%
show_wfs(input_file, keyword, reverse)

# %%
show_stb(input_file, keyword, reverse)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/SET_example_2/unfactored_forward_game_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/SET_example_2/unfactored_forward_game_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div></div>

# %%
# You only need edit this cell
input_file = "files/SET_example_2.lp"
keyword = "game" #arg or game depends on the graphvis_settings.json
reverse = True  # whether you want to reverse the edge direction

# %%
show_wfs(input_file, keyword, reverse)

# %%
show_stb(input_file, keyword, reverse)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/SET_example_2/unfactored_backward_game_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/SET_example_2/unfactored_backward_game_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div></div>
