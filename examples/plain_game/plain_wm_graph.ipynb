# %%
import gamearg as gmg

# %%
gmg_input = gmg.GameArgInput(input_file="plain_wm_graph.lp", keyword="game", reverse=False)

# %%
gmg_input.edge_df
# Out:
#    source target direction
# 0       a      b   forward
# 1       a      c   forward
# 2       k      l   forward
# 3       c      d   forward
# 4       c      e   forward
# 5       l      e   forward
# 6       l      m   forward
# 7       d      e   forward
# 8       e      d   forward
# 9       e      m   forward
# 10      m      e   forward
# 11      d      f   forward
# 12      d      g   forward
# 13      g      d   forward
# 14      e      h   forward
# 15      m      n   forward
# 16      n      m   forward

# %%
wfs = gmg.WfsModel(input_file="plain_wm_graph.lp", keyword="game", reverse=False)
wfs_nodes_df = wfs.wfs_node

# %%
wfs_nodes_df
# Out:
#    node state_id   wfs
# 3     b        0  lost
# 4     f        0  lost
# 5     h        0  lost
# 0     e        1   won
# 1     d        1   won
# 2     a        1   won
# 6     c        2  lost
# 7     g        2  lost
# 8     k        ∞  draw
# 9     l        ∞  draw
# 10    m        ∞  draw
# 11    n        ∞  draw

# %%
stb = gmg.StbModel(input_file="plain_wm_graph.lp", keyword="game", reverse=False)

# %%
stb.stb_node
# Out:
#    node  pw_1  pw_2
# 0     k  lost   won
# 1     b  lost  lost
# 2     l   won  lost
# 3     a   won   won
# 4     m  lost   won
# 5     e   won   won
# 6     g  lost  lost
# 7     f  lost  lost
# 8     c  lost  lost
# 9     n   won  lost
# 10    h  lost  lost
# 11    d   won   won
